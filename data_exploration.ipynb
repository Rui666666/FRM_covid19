# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !mkdir data

# %%
# !wget https://box.hu-berlin.de/f/8f9ccfb57aa8429b9b1f/?dl=1 -O data/keycountries.csv
# Out:
# ...
# --2020-03-27 15:21:47--  https://box.hu-berlin.de/f/8f9ccfb57aa8429b9b1f/?dl=1
# Resolving box.hu-berlin.de (box.hu-berlin.de)... 141.20.184.42
# Connecting to box.hu-berlin.de (box.hu-berlin.de)|141.20.184.42|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://box.hu-berlin.de/seafhttp/files/b1b0bdbe-6714-40f9-882d-0630b0566296/key-countries-pivoted.csv [following]
# --2020-03-27 15:21:47--  https://box.hu-berlin.de/seafhttp/files/b1b0bdbe-6714-40f9-882d-0630b0566296/key-countries-pivoted.csv
# Reusing existing connection to box.hu-berlin.de:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2808 (2.7K) [application/octet-stream]
# Saving to: ‘data/keycountries.csv’
#
# data/keycountries.c 100%[===================>]   2.74K  --.-KB/s    in 0.04s
#
# 2020-03-27 15:21:47 (71.9 KB/s) - ‘data/keycountries.csv’ saved [2808/2808]

# %%
data = pd.read_csv('data/keycountries.csv')

# %%
data.columns
# Out:
# Index(['Date', 'China', 'US', 'United_Kingdom', 'Italy', 'France', 'Germany',
#        'Spain', 'Iran'],
#       dtype='object')

# %%
data.Date = pd.to_datetime(data.Date, format='%Y-%m-%d' )

# %%
plt.plot(data.China, label='China')
plt.plot(data.Italy, label='Italy')
plt.plot(data.US, label='US')
plt.legend()
plt.title('')
# Out:
# Text(0.5, 1.0, '')

# %%
plt.plot(data.China.diff(1))
plt.plot(data.Italy.diff(1))
plt.plot(data.US.diff(1))
